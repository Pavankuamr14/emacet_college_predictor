# %%
import requests
import pandas as pd
import numpy as np
reponse=requests.get('https://raw.githubusercontent.com/rsaikrishnagithub/EAMCET-college-predictor/main/tseamcet.csv')
reponse
# Out:
# <Response [200]>

# %%
# just thing the 200 is successfull for getting requests

# %%
df=pd.DataFrame(reponse)
df.head()
df.
# Out:
#                                                    0
# 0  b'class_id,rank,gender,caste,region,seat_categ...
# 1  b',BC_D_GIRLS_UR,PHD,PHARM - D (M.P.C. STREAM)...
# 2  b'S_GEN_UR,CSE,COMPUTER SCIENCE AND ENGINEERIN...
# 3  b'M,OC,OU,MUS_GEN_UR,CSE,COMPUTER SCIENCE AND ...
# 4  b'0\n1,38165,M,BC_B,OU,MUS_GEN_UR,MIN,MINING E...

# %%
import requests
from io import StringIO
url= 'https://raw.githubusercontent.com/rsaikrishnagithub/EAMCET-college-predictor/main/tseamcet.csv'
s=requests.get(url).content
df=pd.read_csv(StringIO(s.decode('utf-8')))
df
# Out:
#        class_id   rank gender caste region  seat_category branch_code  \
# 0             1  71654      F  BC_B     OU  BC_D_GIRLS_UR         PHD
# 1             1  72609      M  BC_E     OU     MUS_GEN_UR         CSE
# 2             2  43546      M    OC     OU     MUS_GEN_UR         CSE
# 3             1  38165      M  BC_B     OU     MUS_GEN_UR         MIN
# 4             2  71077      M  BC_D     OU     MUS_GEN_UR         MIN
# ...         ...    ...    ...   ...    ...            ...         ...
# 51004         8  40847      M    OC     AU    OC_GIRLS_UR         MEC
# 51005         9  77885      M    ST     OU      ST_GEN_OU         MEC
# 51006        10  56864      M  BC_B     OU    BC_D_GEN_UR         MEC
# 51007        11  36642      M    OC     OU      OC_GEN_UR         MEC
# 51008        12  72967      M  BC_B     OU    BC_B_GEN_OU         MEC
#
#                                  branch college_code  \
# 0             PHARM - D (M.P.C. STREAM)         AVHP
# ...

# %%
import requests
from io import StringIO
url= 'https://raw.githubusercontent.com/rsaikrishnagithub/EAMCET-college-predictor/main/tseamcet.csv'
headers={"user.Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"}
req=requests.get(url,headers=headers)
req
# Out:
# <Response [200]>

# %%
data=StringIO(req.text)
df1=pd.read_csv(data)

# %%
df1
# Out:
#        class_id   rank gender caste region  seat_category branch_code  \
# 0             1  71654      F  BC_B     OU  BC_D_GIRLS_UR         PHD
# 1             1  72609      M  BC_E     OU     MUS_GEN_UR         CSE
# 2             2  43546      M    OC     OU     MUS_GEN_UR         CSE
# 3             1  38165      M  BC_B     OU     MUS_GEN_UR         MIN
# 4             2  71077      M  BC_D     OU     MUS_GEN_UR         MIN
# ...         ...    ...    ...   ...    ...            ...         ...
# 51004         8  40847      M    OC     AU    OC_GIRLS_UR         MEC
# 51005         9  77885      M    ST     OU      ST_GEN_OU         MEC
# 51006        10  56864      M  BC_B     OU    BC_D_GEN_UR         MEC
# 51007        11  36642      M    OC     OU      OC_GEN_UR         MEC
# 51008        12  72967      M  BC_B     OU    BC_B_GEN_OU         MEC
#
#                                  branch college_code  \
# 0             PHARM - D (M.P.C. STREAM)         AVHP
# ...

# %%
df1.isnull().sum()
# Out:
# class_id              0
# rank                  0
# gender                0
# caste                 0
# region                0
# seat_category         0
# branch_code           0
# branch                0
# college_code          0
# college               0
# students_per_class    0
# fee                   0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51009 entries, 0 to 51008
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   class_id            51009 non-null  int64
#  1   rank                51009 non-null  int64
#  2   gender              51009 non-null  object
#  3   caste               51009 non-null  object
#  4   region              51009 non-null  object
#  5   seat_category       51009 non-null  object
#  6   branch_code         51009 non-null  object
#  7   branch              51009 non-null  object
#  8   college_code        51009 non-null  object
#  9   college             51009 non-null  object
#  10  students_per_class  51009 non-null  int64
#  11  fee                 51009 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 4.7+ MB

# %%
df1.to_csv('tsemacet.csv')
